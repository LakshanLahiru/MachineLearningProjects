# %%
#Huggingface

# %%
token = "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"

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = token

# %%
from langchain.llms import HuggingFaceEndpoint

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",temperature=1.0)
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\Lakshan Lahiru\.cache\huggingface\token
# Login successful

# %%
our_query = "Who is Barack Obama in America?"

# %%
completion = llm.invoke(our_query)
print(completion)
# Out:
#  What do people think of him? And how has his presidency affected the nation?
#
# In this intriguing book, former BBC journalist Rajan Datar explores the complex legacy of Barack Obama as both a man and a president. He looks back on his time covering the 44th President of the United States for BBC Radio 4's Today programme, and draws on fresh interviews with key figures from Obama's inner circle, as well as academics, historians, politicians and ordinary Americans, to provide a nuanced and insightful analysis of Obama's achievements and failures.
#
# Obama: The Untold Story goes beyond the soundbites and political controversies to explore what Obama has meant to black America, how he reshaped the political landscape, and what his legacy will be in years to come. The result is an engaging and thought-provoking book about a man who continues to divide opinion, and a presidency that changed the course of American history.
#
# ...

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",temperature=0.7)


# Normaly temperature is varying with 0 to 1.If temperature is closeto 1 then model predicts most probabilitical words,
# if temperature is close to 0 then model predicts random word
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\Lakshan Lahiru\.cache\huggingface\token
# Login successful

# %%
our_query = "Who is Barack Obama in America?"
completion = llm.invoke(our_query)
print(completion)
# Out:
#  He is the 44th President of the United States of America. He is the first African American to hold this office. He was born on August 4, 1961, in Honolulu, Hawaii. Obama served as a senator from Illinois from 2005 to 2008 before running for president. He was elected in 2008 and re-elected in 2012. During his time in office, Obama implemented the Affordable Care Act, also known as Obamacare, which expanded healthcare coverage to millions of Americans. He also oversaw the killing of Osama bin Laden, the mastermind behind the September 11 attacks. Obama left office in January 2017. Since then, he has been living in Washington D.C. with his family. He has written books, given speeches, and worked on various projects through the Obama Foundation. Obama is also a Nobel Peace Prize laureate, which he received in 2009 for his efforts to promote peace and diplomacy.

# %%
# word embedding

# %%
import requests
model_id = "sentence-transformers/all-MiniLM-L6-v2"
hf_token = "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"


api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
headers = {"Authorization": f"Bearer {hf_token}"}

# %%
def query(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts, "options":{"wait_for_model":True}})
    return response.json()

# %%
texts = ["hey buddy"]

# %%
import pandas as pd
output = query(texts)

embeddings = pd.DataFrame(output)

# %%
embeddings
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.071215  0.038797  0.081608 -0.002396  0.082624 -0.083331  0.097735
#
#         7         8         9    ...       374       375       376       377  \
# 0  0.063831  0.028392 -0.018185  ...  0.084726 -0.016101  0.011714  0.014228
#
#         378       379       380       381       382       383
# 0 -0.026466 -0.045392  0.034069  0.058463  0.043555 -0.020041
#
# [1 rows x 384 columns]

# %%
output
# Out:
# [[-0.07121487706899643,
#   0.03879675641655922,
#   0.08160841464996338,
#   -0.0023955360520631075,
#   0.08262353390455246,
#   -0.08333063870668411,
#   0.09773456305265427,
#   0.06383123248815536,
#   0.028391873463988304,
#   -0.018184898421168327,
#   -0.015271617099642754,
#   0.0077461670152843,
#   0.023430410772562027,
#   -0.05783877894282341,
#   -0.005356260109692812,
#   -0.0048998333513736725,
#   0.01340456772595644,
#   -0.04846265912055969,
#   -0.0425681434571743,
#   0.07163850218057632,
#   -0.02039855532348156,
#   0.07733393460512161,
#   0.04105496406555176,
#   -0.07777753472328186,
#   -0.010202695615589619,
#   -0.021201027557253838,
#   0.04364414140582085,
#   0.07980285584926605,
#   -0.09547986090183258,
#   0.027960466220974922,
#   -0.08709044754505157,
#   0.04076715186238289,
#   0.032903965562582016,
#   0.0011219361331313848,
#   0.01644696108996868,
#   -0.02411174401640892,
#   -0.05440855398774147,
#   -0.07093415409326553,
# ...

# %%
#Embedding csv file
import pandas as pd

# %%
df = pd.read_excel("Data.xlsx")

# %%
df["Embedding"] = df["Words"].apply(lambda x: query(x) )

# %%
df
# Out:
#          Words                                          Embedding
# 0     Elephant  [-0.04327397793531418, 0.08806709945201874, 0....
# 1         Lion  [-0.052466899156570435, 0.06620641052722931, -...
# 2        Tiger  [-0.08103104680776596, 0.056832171976566315, -...
# 3          Dog  [-0.053146976977586746, 0.014194401912391186, ...
# 4      Cricket  [0.0226513110101223, 0.08767690509557724, -0.0...
# 5      Footbal  [-0.07466641068458557, 0.03872723877429962, -0...
# 6       Tennis  [0.003770780749619007, 0.029424281790852547, 0...
# 7   Basketball  [0.012926929630339146, 0.05818474292755127, -0...
# 8        Apple  [-0.006138473283499479, 0.031011775135993958, ...
# 9       Orange  [-0.032363131642341614, 0.026842663064599037, ...
# 10      Banana  [-0.05431158468127251, 0.01404563244432211, -0...

# %%
my_text = "mango"
my_text_output = query(my_text)

# %%
my_text_output
# Out:
# [-0.02729090489447117,
#  0.008710948750376701,
#  -0.026596184819936752,
#  0.06313104927539825,
#  0.001076544402167201,
#  0.028661131858825684,
#  0.08205486088991165,
#  -0.03685450926423073,
#  0.012086883187294006,
#  -0.021180061623454094,
#  0.07287682592868805,
#  -0.115090012550354,
#  -0.010580413974821568,
#  -0.04985147342085838,
#  0.06527143716812134,
#  0.013994121924042702,
#  0.07652650028467178,
#  -0.031123118475079536,
#  -0.06877540051937103,
#  -0.0913529098033905,
#  -0.0452708825469017,
#  0.05137280374765396,
#  -0.03986060246825218,
#  0.03419095277786255,
#  -0.03822196647524834,
#  0.021425094455480576,
#  0.0017303841887041926,
#  0.02063329517841339,
#  0.00872323103249073,
#  -0.11703480780124664,
#  0.0020945400465279818,
#  -0.009228751063346863,
#  0.09157291799783707,
#  0.08444700390100479,
#  -0.05675044283270836,
#  -0.0036886557936668396,
#  -0.03189615160226822,
#  -0.06325048953294754,
#  0.036889269948005676,
#  -0.04487823322415352,
# ...

# %%
#check similerity using huggingface ----cosine similarity
from sentence_transformers import SentenceTransformer, util
# Out:
# C:\Users\Lakshan Lahiru\anaconda3\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Lakshan Lahiru\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lakshan Lahiru\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
df["Similerity"] = df["Embedding"].apply(lambda x:util.pytorch_cos_sim(x, my_text_output)  )

# %%
df.sort_values(by="Similerity",ascending=False)
# Out:
#          Words                                          Embedding  \
# 10      Banana  [-0.05431158468127251, 0.01404563244432211, -0...
# 2        Tiger  [-0.08103104680776596, 0.056832171976566315, -...
# 9       Orange  [-0.032363131642341614, 0.026842663064599037, ...
# 8        Apple  [-0.006138473283499479, 0.031011775135993958, ...
# 0     Elephant  [-0.04327397793531418, 0.08806709945201874, 0....
# 4      Cricket  [0.0226513110101223, 0.08767690509557724, -0.0...
# 1         Lion  [-0.052466899156570435, 0.06620641052722931, -...
# 7   Basketball  [0.012926929630339146, 0.05818474292755127, -0...
# 3          Dog  [-0.053146976977586746, 0.014194401912391186, ...
# 6       Tennis  [0.003770780749619007, 0.029424281790852547, 0...
# 5      Footbal  [-0.07466641068458557, 0.03872723877429962, -0...
#
#             Similerity
# 10  [[tensor(0.5250)]]
# 2   [[tensor(0.4756)]]
# 9   [[tensor(0.4330)]]
# 8   [[tensor(0.4006)]]
# 0   [[tensor(0.3594)]]
# 4   [[tensor(0.3591)]]
# ...
